# %% [markdown]
# <a href="https://colab.research.google.com/github/moniquevernon/OBIS-Training/blob/main/Seagrass_test_Belize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyobis
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 4.7 MB/s eta 0:00:00
# ...

# %%
from pyobis import occurrences

data = occurrences.search(scientificname="Mola mola", size=10).execute()
result = occurrences.search(
    geometry="POLYGON((30.1 10.1, 10 20, 20 40, 40 40, 30.1 10.1))", size=20
).execute()

# %%
result
# Out:
#                                          accessRights       basisOfRecord  \
# 0   https://members.oceantrack.org/data/policies/o...  MachineObservation
# 1                                                 NaN      MaterialSample
# 2                                                 NaN     MATERIAL_SAMPLE
# 3                                                 NaN          Occurrence
# 4                                                 NaN   PreservedSpecimen
# 5                                                 NaN    HumanObservation
# 6                                                 NaN          Occurrence
# 7                                                 NaN    HumanObservation
# 8                                                 NaN    HumanObservation
# 9                                                 NaN     MATERIAL_SAMPLE
# 10                                                NaN   PreservedSpecimen
# 11                                                NaN    HumanObservation
# ...
